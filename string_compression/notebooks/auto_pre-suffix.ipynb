# %%
import pandas as pd
import os
import json
from utils import (
    write_parquet,
    get_df,
    compare_dataframes,
    get_size,
    filter_sample_df,
    get_pre_suffix
)

dataset_id = "nhagar/fineweb_urls"
dataset_config = ""
configs_file = "config.json"
config_dict = json.load(open(configs_file, "r"))[dataset_id]

# %%
df = get_df(config_dict['configs'][0]['path'])
print(df.head())
# Out:
#                                                  url                   domain
# 0  http://0ncemorewithfeeling.blogspot.com/2010/1...             blogspot.com
# 1  http://1001plus.blogspot.com/2011/11/very-shor...             blogspot.com
# 2  http://101bestandbrightest.com/companies/aviso...  101bestandbrightest.com
# 3  http://101bestandbrightest.com/companies/field...  101bestandbrightest.com
# 4    http://10pointsmanagement.com/the-wizard-of-oz/   10pointsmanagement.com

# %%
sampled_df, string_columns = filter_sample_df(df)
# sampled_df = sampled_df.map(lambda x: x.replace('"', '') if isinstance(x, str) else x)
# sampled_df = sampled_df[['product_name', 'product_hashisy', 'product_smiles']]
# sampled_df = sampled_df.drop(columns=['pains_filter_match_name', 'lhasa_scoring_history', 'lhasa_reaction_warnings', 'pains_filter_match_name'])
string_columns = sampled_df.select_dtypes(include=['object', 'string']).columns

# %%
results = get_pre_suffix(sampled_df, string_columns)
# Out:
# Comparing 2 string columns for prefix and suffix matches...
# Filter threshold set to 0.90
# Processing (2/2)

# %%
results
# Out:
# [{'col1': 'url',
#   'col2': 'domain',
#   'containment_ratio': np.float64(1.0),
#   'infix_match': np.float64(1.0)}]

# %%
# statistic len of domain
sampled_df['domain_len'] = sampled_df['domain'].apply(lambda x: len(x))
# min and max length of domain
print(f"Min domain length: {sampled_df['domain_len'].min()}")
print(f"Max domain length: {sampled_df['domain_len'].max()}")
print(f"Mean domain length: {sampled_df['domain_len'].mean()}")

df['domain_offset'] = df.apply(lambda row: row['url'].find(row['domain']) if row['url'].find(row['domain']) > 0 else 0, axis=1)
# min and max offset of domain in url
print(f"Min domain offset: {df['domain_offset'].min()}")
print(f"Max domain offset: {df['domain_offset'].max()}")
print(f"Mean domain offset: {df['domain_offset'].mean()}")
# Out:
# Min domain length: 5
# Max domain length: 42
# Mean domain length: 14.7158
# Min domain offset: 0
# Max domain offset: 84
# Mean domain offset: 12.637715

# %%
config_dict = json.load(open(configs_file, "r"))
dataset_ids = config_dict.keys()
for dataset_id in dataset_ids:
    print(f"\n\nProcessing dataset: {dataset_id}")
    config = config_dict[dataset_id]
    df = get_df(config['configs'][0]['path'])
    sampled_df, string_columns = filter_sample_df(df)
    results = get_pre_suffix(sampled_df, string_columns)
    print(f"\nResults: {results}")
    with open(f"results/{dataset_id.replace("/", "_")}_results.json", "w") as f:
        json.dump(results, f, indent=4)
# Out:
# Processing dataset: wikimedia/wikipedia
# Comparing 4 string columns for prefix and suffix matches...
# Filter threshold set to 0.90
# Processing (12/12)
# Results: [{'col1': 'text', 'col2': 'title', 'containment_ratio': np.float64(0.9094426287601287)}]
#
#
# Processing dataset: HuggingFaceFW/fineweb
# Comparing 7 string columns for prefix and suffix matches...
# Filter threshold set to 0.90
# Processing (42/42)
# Results: [{'col1': 'file_path', 'col2': 'dump', 'containment_ratio': np.float64(1.0), 'infix_match': np.float64(1.0)}]
#
#
# Processing dataset: Metanova/SAVI-2020
# Comparing 38 string columns for prefix and suffix matches...
# Filter threshold set to 0.90
# Processing (1406/1406)
# Results: [{'col1': 'product_name', 'col2': 'product_hashisy', 'containment_ratio': np.float64(0.9444444444444445), 'prefix_match': np.float64(1.0)}, {'col1': 'product_name', 'col2': 'product_stereo_tauto_hash', 'containment_ratio': np.float64(0.9134222222222222), 'prefix_match': np.float64(0.9712)}, {'col1': 'product_hashisy', 'col2': 'product_stereo_tauto_hash', 'equal_match': np.float64(0.963), 'containment_ratio': np.float64(0.9664611111111111), 'prefix_match': np.float64(0.9781)}, {'col1': 'product_stereo_tauto_hash', 'col2': 'product_hashisy', 'equal_match': np.float64(0.963), 'containment_ratio': np.float64(0.9664611111111111), 'prefix_match': np.float64(0.9781)}, {'col1': 'lhasa_scoring_history', 'col2': 'pains_filter_match_name', 'equal_match': np.float64(0.9905), 'containment_ratio': np.float64(0.9911207422969188), 'prefix_match': np.float64(1.0)}, {'col1': 'lhasa_scoring_history', 'col2': 'lhasa_reaction_warnings', 'equal_match': np.float64(1.0)}, {'col1': 'lhasa_reaction_warnings', 'col2': 'pains_filter_match_name', 'equal_match': np.float64(0.9905), 'containment_ratio': np.float64(0.9911207422969188), 'prefix_match': np.float64(1.0)}, {'col1': 'lhasa_reaction_warnings', 'col2': 'lhasa_scoring_history', 'equal_match': np.float64(1.0)}, {'col1': 'r1_bbsource', 'col2': 'r2_bbsource', 'equal_match': np.float64(1.0)}, {'col1': 'r1_url', 'col2': 'r1_ident', 'containment_ratio': np.float64(0.9230769230769232)}, {'col1': 'r2_bbsource', 'col2': 'r1_bbsource', 'equal_match': np.float64(1.0)}, {'col1': 'r2_url', 'col2': 'r2_ident', 'containment_ratio': np.float64(0.9285831868131869)}]
#
#
# Processing dataset: bigdata-pw/Flickr
# Comparing 39 string columns for prefix and suffix matches...
# Filter threshold set to 0.90
# Processing (1482/1482)
# Results: [{'col1': 'url_sq', 'col2': 'id', 'containment_ratio': np.float64(1.0), 'infix_match': np.float64(1.0)}, {'col1': 'url_sq', 'col2': 'url_q', 'containment_ratio': np.float64(0.9212059327862558), 'prefix_match': np.float64(1.0)}, {'col1': 'url_sq', 'col2': 'url_t', 'containment_ratio': np.float64(0.9212059327862558), 'prefix_match': np.float64(1.0)}, {'col1': 'url_sq', 'col2': 'url_s', 'containment_ratio': np.float64(0.9212059327862558), 'prefix_match': np.float64(1.0)}, {'col1': 'url_sq', 'col2': 'url_n', 'containment_ratio': np.float64(0.9212059327862558), 'prefix_match': np.float64(1.0)}, {'col1': 'url_sq', 'col2': 'url_w', 'containment_ratio': np.float64(0.9212059327862558), 'prefix_match': np.float64(1.0)}, {'col1': 'url_sq', 'col2': 'url_m', 'containment_ratio': np.float64(0.934819597737723), 'prefix_match': np.float64(0.9999)}, {'col1': 'url_sq', 'col2': 'url_z', 'containment_ratio': np.float64(0.9208371827862558), 'prefix_match': np.float64(0.9996)}, {'col1': 'url_sq', 'col2': 'url_c', 'containment_ratio': np.float64(0.9202844338103214), 'prefix_match': np.float64(0.999)}, {'col1': 'url_sq', 'col2': 'url_l', 'containment_ratio': np.float64(0.916044436850516), 'prefix_match': np.float64(0.9944)}, {'col1': 'url_q', 'col2': 'id', 'containment_ratio': np.float64(1.0), 'infix_match': np.float64(1.0)}, {'col1': 'url_q', 'col2': 'url_sq', 'containment_ratio': np.float64(0.9212059327862558), 'prefix_match': np.float64(1.0)}, {'col1': 'url_q', 'col2': 'url_t', 'containment_ratio': np.float64(0.9212059327862558), 'prefix_match': np.float64(1.0)}, {'col1': 'url_q', 'col2': 'url_s', 'containment_ratio': np.float64(0.9212059327862558), 'prefix_match': np.float64(1.0)}, {'col1': 'url_q', 'col2': 'url_n', 'containment_ratio': np.float64(0.9212059327862558), 'prefix_match': np.float64(1.0)}, {'col1': 'url_q', 'col2': 'url_w', 'containment_ratio': np.float64(0.9212059327862558), 'prefix_match': np.float64(1.0)}, {'col1': 'url_q', 'col2': 'url_m', 'containment_ratio': np.float64(0.934819597737723), 'prefix_match': np.float64(0.9999)}, {'col1': 'url_q', 'col2': 'url_z', 'containment_ratio': np.float64(0.9208371827862558), 'prefix_match': np.float64(0.9996)}, {'col1': 'url_q', 'col2': 'url_c', 'containment_ratio': np.float64(0.9202844338103214), 'prefix_match': np.float64(0.999)}, {'col1': 'url_q', 'col2': 'url_l', 'containment_ratio': np.float64(0.916044436850516), 'prefix_match': np.float64(0.9944)}, {'col1': 'url_t', 'col2': 'id', 'containment_ratio': np.float64(1.0), 'infix_match': np.float64(1.0)}, {'col1': 'url_t', 'col2': 'url_sq', 'containment_ratio': np.float64(0.9212059327862558), 'prefix_match': np.float64(1.0)}, {'col1': 'url_t', 'col2': 'url_q', 'containment_ratio': np.float64(0.9212059327862558), 'prefix_match': np.float64(1.0)}, {'col1': 'url_t', 'col2': 'url_s', 'containment_ratio': np.float64(0.9212059327862558), 'prefix_match': np.float64(1.0)}, {'col1': 'url_t', 'col2': 'url_n', 'containment_ratio': np.float64(0.9212059327862558), 'prefix_match': np.float64(1.0)}, {'col1': 'url_t', 'col2': 'url_w', 'containment_ratio': np.float64(0.9212059327862558), 'prefix_match': np.float64(1.0)}, {'col1': 'url_t', 'col2': 'url_m', 'containment_ratio': np.float64(0.934819597737723), 'prefix_match': np.float64(0.9999)}, {'col1': 'url_t', 'col2': 'url_z', 'containment_ratio': np.float64(0.9208371827862558), 'prefix_match': np.float64(0.9996)}, {'col1': 'url_t', 'col2': 'url_c', 'containment_ratio': np.float64(0.9202844338103214), 'prefix_match': np.float64(0.999)}, {'col1': 'url_t', 'col2': 'url_l', 'containment_ratio': np.float64(0.916044436850516), 'prefix_match': np.float64(0.9944)}, {'col1': 'url_s', 'col2': 'id', 'containment_ratio': np.float64(1.0), 'infix_match': np.float64(1.0)}, {'col1': 'url_s', 'col2': 'url_sq', 'containment_ratio': np.float64(0.9212059327862558), 'prefix_match': np.float64(1.0)}, {'col1': 'url_s', 'col2': 'url_q', 'containment_ratio': np.float64(0.9212059327862558), 'prefix_match': np.float64(1.0)},  ...

# %%
config_dict = json.load(open(configs_file, "r"))
dataset_ids = ["vCache/SemBenchmarkLmArena", "vCache/SemBenchmarkClassification"]
for dataset_id in dataset_ids:
    print(f"\n\nProcessing dataset: {dataset_id}")
    config = config_dict[dataset_id]
    df = get_df(config['configs'][0]['path'])
    sampled_df, string_columns = filter_sample_df(df)
    print(f"String columns: {string_columns}")
    string_columns = string_columns[[not col.startswith("emb") for col in string_columns]]
    results = get_pre_suffix(sampled_df, string_columns)
    print(f"\nResults: {results}")
    with open(f"results/{dataset_id.replace("/", "_")}_results.json", "w") as f:
        json.dump(results, f, indent=4)
# Out:
# Processing dataset: vCache/SemBenchmarkLmArena
# String columns: Index(['task', 'dataset_name', 'output_format', 'text',
#        'emb_text-embedding-3-large', 'emb_text-embedding-3-small',
#        'response_gpt-4o-mini', 'response_gpt-4.1-nano', 'emb_gte',
#        'emb_gte_ft', 'emb_e5_large_v2', 'emb_e5_large_v2_ft'],
#       dtype='object')
# Comparing 6 string columns for prefix and suffix matches...
# Filter threshold set to 0.90
# Processing (30/30)
# Results: [{'col1': 'task', 'col2': 'text', 'equal_match': np.float64(1.0)}, {'col1': 'text', 'col2': 'task', 'equal_match': np.float64(1.0)}]
#
#
# Processing dataset: vCache/SemBenchmarkClassification
# String columns: Index(['dataset_name', 'task', 'output_format', 'text', 'emb_gte',
#        'emb_gte_ft', 'emb_e5_mistral_7b', 'emb_e5_large_v2',
#        'emb_e5_large_v2_ft', 'response_llama_3_8b', 'response_llama_3_70b'],
#       dtype='object')
# Comparing 6 string columns for prefix and suffix matches...
# Filter threshold set to 0.90
# Processing (30/30)
# Results: [{'col1': 'output_format', 'col2': 'response_llama_3_8b', 'containment_ratio': np.float64(0.9999428571428572), 'infix_match': np.float64(0.9999)}, {'col1': 'output_format', 'col2': 'response_llama_3_70b', 'containment_ratio': np.float64(0.9919661904761904), 'infix_match': np.float64(0.9995)}]

# %%
from search_hf_datasets_openai import process_dataset

result = process_dataset("nhagar/fineweb_urls")
print(f"Processed dataset result: {result}")
# Out:
# Processing dataset: nhagar/fineweb_urls with configs: ['default']
# Processing splits: dict_keys(['train']) for dataset: nhagar/fineweb_urls/default
# Trying sample_n=1000 → CSV string length: 87633
# Trying sample_n=500 → CSV string length: 44126
# Trying sample_n=250 → CSV string length: 22344
# Trying sample_n=125 → CSV string length: 11433
# Trying sample_n=62 → CSV string length: 5612
# OpenAI response: To analyze the string columns in the provided CSV sample, we will follow the steps outlined in your instructions. Our focus will be on detecting if one string is a prefix, suffix, or infix of another string in the two columns: `url` and `domain`.
#
# Here’s the analysis based on the provided data:
#
# 1. **Identify Columns with String Values**:
#    - The columns in the DataFrame are `url` and `domain`, both of which contain string values.
#
# 2. **Compare Rows for String Relationships**:
#    - We will compare each value in `url` to each value in `domain` and check for the three specified relationships (prefix, suffix, infix).
#
# 3. **Reporting Matches**:
#    - For each unique pair of columns, we will report the matches only once, even if they occur in multiple rows.
#
# After analyzing the data, the following relationships have been detected:
#
# - The `url` string is a prefix of its corresponding `domain` string.
# - The `domain` strings are in some cases infixes within the `url`.
#
# ### Matches Detected:
#
# 1. **Infix relationships**:
#    - Each `domain` is an infix of its corresponding `url`.
#    - Example relationships:
#      - `url`: `http://www.rcuniverse.com/magazine/article_display.cfm?article_id=1140`
#        - `domain`: `rcuniverse.com`
#      - `url`: `http://isabellethissaintjean.com/how-much-does-it-cost-to-remodel-a-kitchen.html`
#        - `domain`: `isabellethissaintjean.com`
#      - And so on...
#
# ### Resulting Output:
#
# Here's the structured output based on our analysis:
#
# ```python
# matches = [
#     {"col1": "url", "col2": "domain", "type": "infix"},
# ]
# ```
#
# Since we only detected `infix` relationships and reported them once per column pair, our final output contains the detected relationships as specified.
#
# If no relationships had been found, we would have returned an empty list `[]`.
# Extracted result: [{'col1': 'url', 'col2': 'domain', 'type': 'infix'}]
# Processed dataset result: {'nhagar/fineweb_urls/combined': {'status': 'match', 'result': [{'col1': 'url', 'col2': 'domain', 'type': 'infix'}]}}
